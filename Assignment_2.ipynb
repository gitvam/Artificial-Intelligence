# %% [markdown]
# # SUDOKU
#
# Student Number = csd4112
#
# Name = George Vamvakousis

# %%
from csp import *
from search import *
# %matplotlib inline
from notebook import *
# Hide warnings in the matplotlib sections
import warnings
warnings.filterwarnings("ignore")
from sudokuParam import *
from sudoku_puzzles import *
#psource(Sudoku)

# %%
# # 1. Set up the puzzle.
# Examples
puzzle = puzzle16x16 #Solve the 16x16 puzzle with backtracking_search(puzzle,mrv,unordered_domain_values, forward_checking)
print("Start:")
puzzle.display(puzzle.infer_assignment())
# Out:
# Start:
# . 11 09 16 | 14 03 01 . | . 05 02 . | . 08 . .
# . . . 14 | 04 15 06 . | 12 . . . | 02 . . 03
# 15 . . . | . 02 . 11 | 13 . 01 . | . . 05 04
# . . . . | 05 07 . . | 03 08 . . | . . . 09
# ------+-------+------
# 11 12 . . | . 05 . . | . . . . | 08 09 . 07
# 03 . . . | . . . . | . . . . | 10 . 04 13
# 01 05 07 04 | . . . . | . . 06 14 | . 12 02 15
# 08 14 06 02 | 09 . . . | . . . 10 | . . . .
# ------+-------+------
# . . . . | 03 . . . | . . . 02 | 07 13 09 01
# 02 07 05 . | 10 06 . . | . . . . | 04 03 15 12
# 06 16 . 11 | . . . . | . . . . | . . . 02
# 13 . 04 09 | . . . . | . . 05 . | . . 10 06
# ------+-------+------
# 12 . . . | . . 03 02 | . . 16 04 | . . . .
# 09 04 . . | . 10 . 12 | 14 . 15 . | . . . 11
# 16 . . 03 | . . . 05 | . 06 11 13 | 15 . . .
# . . 10 . | . 16 15 . | . 07 09 12 | 13 04 03 .

# %%
# 2a. Solve the puzzle using search algorithms
#result = depth_first_graph_search(puzzle)                   # <- search algorithm with default parameters
#AC3(puzzle)                                         #<- constraint propagation algorithm
#AC3b(puzzle)                                        #<- constraint propagation algorithm
#AC4(puzzle)                                         #<- constraint propagation algorithm
#result = backtracking_search(puzzle)                 #<- search algorithm with default parameters
result = backtracking_search(puzzle,mrv,unordered_domain_values, forward_checking) #<- search algorithm with heuristics and inference
#min_conflicts(puzzle)                               #<- search algorithm with default parameters

# # 3a. Print the results.  
print
if puzzle.goal_test(puzzle.infer_assignment()):
    print("Solution:")
    puzzle.display(puzzle.infer_assignment())
else:
    print("Failed - domains: " + str(puzzle.curr_domains))
    puzzle.display(result)
# Out:
# Solution:
# 07 11 09 16 | 14 03 01 13 | 04 05 02 15 | 12 08 06 10
# 05 13 01 14 | 04 15 06 08 | 12 10 07 09 | 02 16 11 03
# 15 10 03 08 | 12 02 09 11 | 13 16 01 06 | 14 07 05 04
# 04 02 12 06 | 05 07 16 10 | 03 08 14 11 | 01 15 13 09
# ------+-------+------
# 11 12 13 10 | 15 05 02 06 | 16 04 03 01 | 08 09 14 07
# 03 09 16 15 | 01 12 11 14 | 05 02 08 07 | 10 06 04 13
# 01 05 07 04 | 16 08 10 03 | 09 13 06 14 | 11 12 02 15
# 08 14 06 02 | 09 13 07 04 | 15 11 12 10 | 03 05 01 16
# ------+-------+------
# 10 08 14 12 | 03 11 05 16 | 06 15 04 02 | 07 13 09 01
# 02 07 05 01 | 10 06 08 09 | 11 14 13 16 | 04 03 15 12
# 06 16 15 11 | 13 04 12 07 | 01 09 10 03 | 05 14 08 02
# 13 03 04 09 | 02 01 14 15 | 07 12 05 08 | 16 11 10 06
# ------+-------+------
# 12 15 11 13 | 06 14 03 02 | 08 01 16 04 | 09 10 07 05
# 09 04 02 07 | 08 10 13 12 | 14 03 15 05 | 06 01 16 11
# 16 01 08 03 | 07 09 04 05 | 10 06 11 13 | 15 02 12 14
# 14 06 10 05 | 11 16 15 01 | 02 07 09 12 | 13 04 03 08

# %%
# 2b. Solve a puzzle defined in sudoku_puzzles.py.
#puzzle16x16.display(puzzle16x16.infer_assignment())
# Puzzle.infer_assignment() will have solution IF search algorithm converged to a solution. 
# Result will have the latest inference of the puzzle.
# IF depth_first_graph_search or other search algorithms from search.py are used, due to use of different objects
# puzzle.display() will not be callable and a simple print will help you visualise the results.
"""######################################################################################################################
       100x100 too large to display in notebook due to memory..if u want visuals use another environment, eg. PyCharm
######################################################################################################################"""
# puzzle100x100.display(puzzle100x100.infer_assignment())
####################
x = random.randint(0, 107) #<---- choose a random puzzle of the puzzles
puzzle = Sudoku(puzzles[x]) #<---- create Sudoku object by calling the string at a random position x of the list
 
#result = depth_first_graph_search(puzzle)
#result = backtracking_search(puzzle,mrv,unordered_domain_values, forward_checking)
#result = backtracking_search(puzzle)
result = backtracking_search(puzzle,mrv,unordered_domain_values, forward_checking)
#min_conflicts(puzzle)

# 3b. Print the results.  
print
if puzzle.goal_test(puzzle.infer_assignment()):
    print("Solution:")
    puzzle.display(puzzle.infer_assignment())
else:
    print("Failed - domains: " + str(puzzle.curr_domains))
    puzzle.display(result)
# Out:
# Solution:
# 6 1 5 | 3 8 2 | 4 7 9
# 9 4 3 | 7 6 5 | 8 1 2
# 8 2 7 | 4 9 1 | 5 3 6
# ------+-------+------
# 7 5 2 | 6 3 4 | 1 9 8
# 1 6 8 | 2 7 9 | 3 5 4
# 3 9 4 | 5 1 8 | 6 2 7
# ------+-------+------
# 2 8 6 | 1 5 7 | 9 4 3
# 5 7 9 | 8 4 3 | 2 6 1
# 4 3 1 | 9 2 6 | 7 8 5

# %%
x = random.randint(0, 107) #<---- choose a random puzzle of the puzzles
puzzle = Sudoku(puzzles[x]) #<---- create Sudoku object by calling the string at a random position x of the list
 
result = backtracking_search(puzzle,mrv,unordered_domain_values, forward_checking)

# 3b. Print the results.  
print
if puzzle.goal_test(puzzle.infer_assignment()):
    print("Solved")
else:
    print("Failed")
# Out:
# Solved

# %%
"""######################################################################################################################
     MODIFYING CLASS OF SUDOKU FOR LARGER SIZES. Size is parameterised by value _SIZEA=4 or _SIZEB=10 in sudokuParam.py
     classes are duplicated in essence but twitched so without deviating at all from the book source code you
     can solve with the same script 9x9, 16x16, 100x100 puzzles
######################################################################################################################"""
#psource(SudokuParam)
#psource(Sudoku100x100)
# Out:
# '######################################################################################################################\n     MODIFYING CLASS OF SUDOKU FOR LARGER SIZES. Size is parameterised by value _SIZEA=4 or _SIZEB=10 in sudokuParam.py\n     classes are duplicated in essence but twitched so without deviating at all from the book source code you\n     can solve with the same script 9x9, 16x16, 100x100 puzzles\n######################################################################################################################'

# %%
from numpy.random import default_rng
choice = 1 #<- how many puzzles
rng = default_rng() #<- set random seed to default for repetiveness
randomSudokuList = np.sort(rng.choice(len(puzzles), size=(1,choice), replace = False)) #<- uniformely choose unique puzzles
randomSudokuList = randomSudokuList[0] # <- unravel list
for i in randomSudokuList: # <- iterate lists
    puzzle = Sudoku(puzzles[i])
    puzzle.display(puzzle.infer_assignment())
# Out:
# . 4 7 | . 8 . | . . 1
# . . . | . . . | . . .
# . . . | 6 . . | 7 . .
# ------+-------+------
# 6 . . | . . 3 | 5 7 .
# . . . | . . 5 | . . .
# . 1 . | . 6 . | . . .
# ------+-------+------
# 2 8 . | . 4 . | . . .
# . 9 . | 1 . . | . 4 .
# . . . | . 2 . | 6 9 .

# %%
# define method that penalises solution in case of conflicts or empty tiles based on code in csp.py
# it works for CPS objects and not for Node objects so will need makeover for algorithms in search.py
def evaluateSudoku(puzzle):
    tmp = 0
    for i in range(len(puzzle.infer_assignment())):
        if i in puzzle.infer_assignment():
            tmp += puzzle.nconflicts(i, puzzle.infer_assignment()[i],puzzle.infer_assignment())
    return tmp*20+(81-len(puzzle.infer_assignment()))*10

puzzle = Sudoku(puzzles[1])
backtracking_search(puzzle,mrv,unordered_domain_values, forward_checking)
puzzle.display(puzzle.infer_assignment())
print()
print('Solution Penalty Score: ' + str(evaluateSudoku(puzzle)))
# Out:
# 4 1 7 | 3 6 9 | 8 2 5
# 6 3 2 | 1 5 8 | 9 4 7
# 9 5 8 | 7 2 4 | 3 1 6
# ------+-------+------
# 8 2 5 | 4 3 7 | 1 6 9
# 7 9 1 | 5 8 6 | 4 3 2
# 3 4 6 | 9 1 2 | 7 5 8
# ------+-------+------
# 2 8 9 | 6 4 3 | 5 7 1
# 5 7 3 | 2 9 1 | 6 8 4
# 1 6 4 | 8 7 5 | 2 9 3
#
# Solution Penalty Score: 0

# %%
# Write code that iteratively calls a random selections of puzzles and evaluate their solution and their execution time.
# experiment with inputs of backtracking_search and min_conflicts methods found in csp.py

# %%
puzzle_100 = puzzle100x100
print("Start:")
#puzzle_100.display(puzzle_100.infer_assignment())

#result = backtracking_search(puzzle_100,mrv,unordered_domain_values, forward_checking) #<- search algorithm with heuristics and inference
#result = depth_first_graph_search(puzzle_100)
result = backtracking_search(puzzle_100)

print
if puzzle_100.goal_test(puzzle_100.infer_assignment()):
    print("Solution:")
    #puzzle_100.display(puzzle_100.infer_assignment())
else:
    print("Failed - domains: " + str(puzzle_100.curr_domains))
    #puzzle_100.display(result)
# Out:
# Start:
# Failed - domains: {0: ['089'], 1: ['093'], 2: ['030'], 3: ['041'], 4: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064', '065', '066', '067', '068', '069', '070', '071', '072', '073', '074', '075', '076', '077', '078', '079', '080', '081', '082', '083', '084', '085', '086', '087', '088', '089', '090', '091', '092', '093', '094', '095', '096', '097', '098', '099', '0100', '0100', '016'], 5: ['002', '001', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064', '065', '066', '067', '068', '069', '070', '071', '072', '073', '074', '075', '076', '077', '078', '079', '080', '081', '082', '083', '084', '085', '086', '087', '088', '089', '090', '091', '092', '093', '094', '095', '096', '097', '098', '099', '0100', '0100', '016'], 6: ['003', '001', '002', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064', '065', '066', '067', '068', '069', '070', '071', '072', '073', '074', '075', '076', '077', '078', '079', '080', '081', '082', '083', '084', '085', '086', '087', '088', '089', '090', '091', '092', '093', '094', '095', '096', '097', '098', '099', '0100', '0100', '016'], 7: ['082'], 8: ['004', '001', '002', '003', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064', '065', '066', '067', '068', '069', '070', '071', '072', '073', '074', '075', '076', '077', '078', '079', '080', '081', '082', '083', '084', '085', '086', '087', '088', '089', '090', '091', '092', '093', '094', '095', '096', '097', '098', '099', '0100', '0100', '016'], 9: ['080'], 100: ['063'], 101: ['028'], 102: ['007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '029', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '042', '043', '044', '045', '046', '047', '006', '005', '001', '002', '003', '004', '028', '030', '041', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064', '065', '066', '067', '068', '069', '070', '071', '072', '073', '074', '075', '076', '077', '078', '079', '080', '081', '082', '083', '084', '085', '086', '087', '088', '089', '090', '091', '092', '093', '094', '095', '096', '097', '098', '099', '0100', '0100'], 103: ['008', '010', '012', '014', '016', '018', '020', '022', '024', '026', '029', '032', '034', '036', '038', '040', '043', '045', '047', '005', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '064', '065', '066', '067', '068', '069', '070', '071', '072', '0 ...
